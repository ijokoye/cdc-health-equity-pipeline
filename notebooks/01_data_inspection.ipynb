# %%
import pandas as pd

# %%
path = "/Users/ijeomaokoye/IdeaProjects/cdc-health-equity-pipeline/data/raw/PLACES__Local_Data_for_Better_Health,_County_Data_2024_release_20260223.csv"
df = pd.read_csv(path)
# Out:
# /var/folders/vy/xpvc54xn23d76mxsc464kqz80000gn/T/ipykernel_67096/1873280665.py:2: DtypeWarning: Columns (0: Data_Value_Footnote_Symbol, 1: Data_Value_Footnote) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
# how big is it
print(df.shape)

print("-----------------------------")
df.info()   #info about it

print("-----------------------------")
display(df.head(5))
display(df.sample(5,random_state=42))

# columns and data types
# display(df.dtypes)

# missingness
missing = df.isna().mean().sort_values(ascending=False)
display(missing.head(25))

# key geography fields (adjust names as needed)
for col in ["StateAbbr", "CountyName", "LocationName", "GeoLocation", "TractFIPS", "CountyFIPS", "StateFIPS"]:
    if col in df.columns:
        print(col, "unique:", df[col].nunique(), "missing:", df[col].isna().sum())
# Out:
# (240886, 22)
# -----------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 240886 entries, 0 to 240885
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Year                        240886 non-null  int64
#  1   StateAbbr                   240886 non-null  str
#  2   StateDesc                   240886 non-null  str
#  3   LocationName                240806 non-null  str
#  4   DataSource                  240886 non-null  str
#  5   Category                    240886 non-null  str
#  6   Measure                     240886 non-null  str
#  7   Data_Value_Unit             240886 non-null  str
#  8   Data_Value_Type             240886 non-null  str
#  9   Data_Value                  240886 non-null  float64
#  10  Data_Value_Footnote_Symbol  14 non-null      str
#  11  Data_Value_Footnote         14 non-null      str
# ...
