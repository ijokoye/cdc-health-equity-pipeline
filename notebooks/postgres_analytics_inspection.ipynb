# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql+psycopg2://ijeomaokoye@localhost:5432/health_equity")
df = pd.read_sql_query("SELECT * FROM analytics.stg_places_cleaned LIMIT 20", engine)
display(df)
# Out:
#     year state_abbr state_desc  location_name data_source  \
# 0   2022         AL    Alabama           Clay       BRFSS
# 1   2022         AL    Alabama           Dale       BRFSS
# 2   2022         AL    Alabama        Jackson       BRFSS
# 3   2022         AL    Alabama     Lauderdale       BRFSS
# 4   2022         AL    Alabama       Lawrence       BRFSS
# 5   2022         AL    Alabama            Lee       BRFSS
# 6   2022         AL    Alabama            Lee       BRFSS
# 7   2022         AL    Alabama        Marengo       BRFSS
# 8   2022         AL    Alabama         Marion       BRFSS
# 9   2021         AL    Alabama         Mobile       BRFSS
# 10  2022         AL    Alabama        Pickens       BRFSS
# 11  2022         AK     Alaska     Dillingham       BRFSS
# 12  2022         AK     Alaska         Haines       BRFSS
# 13  2022         AK     Alaska  Kodiak Island       BRFSS
# 14  2022         AZ    Arizona           Yuma       BRFSS
# 15  2022         AR   Arkansas         Baxter       BRFSS
# 16  2022         AR   Arkansas         Benton       BRFSS
# 17  2022         AR   Arkansas         Chicot       BRFSS
# 18  2022         AR   Arkansas       Columbia       BRFSS
# 19  2022         AR   Arkansas       Columbia       BRFSS
#
#                  category                           measure data_value_unit  \
# 0         Health Outcomes       Current asthma among adults               %
# 1         Health Outcomes            Arthritis among adults               %
# 2         Health Outcomes               Stroke among adults               %
# 3         Health Outcomes              Obesity among adults               %
# 4              Disability       Any disability among adults               %
# 5   Health Risk Behaviors       Binge drinking among adults               %
# 6         Health Outcomes               Stroke among adults               %
# 7   Health Risk Behaviors       Binge drinking among adults               %
# 8         Health Outcomes               Stroke among adults               %
# 9         Health Outcomes  High blood pressure among adults               %
# 10        Health Outcomes            Arthritis among adults               %
# 11        Health Outcomes              Obesity among adults               %
# 12        Health Outcomes            Arthritis among adults               %
# 13        Health Outcomes              Obesity among adults               %
# 14        Health Outcomes            Arthritis among adults               %
# 15        Health Outcomes   Diagnosed diabetes among adults               %
# 16        Health Outcomes               Stroke among adults               %
# 17        Health Outcomes           Depression among adults               %
# 18        Health Outcomes            Arthritis among adults               %
# 19        Health Outcomes               Stroke among adults               %
#
#             data_value_type  data_value  ... low_confidence_limit  \
# 0          Crude prevalence        11.0  ...                  9.6
# 1          Crude prevalence        35.6  ...                 34.8
# 2          Crude prevalence         5.1  ...                  4.6
# 3   Age-adjusted prevalence        36.5  ...                 29.6
# 4          Crude prevalence        40.1  ...                 35.5
# 5   Age-adjusted prevalence        15.8  ...                 12.8
# 6          Crude prevalence         3.3  ...                  3.0
# 7   Age-adjusted prevalence        13.7  ...                 11.0
# 8   Age-adjusted prevalence         4.0  ...                  3.6
# 9   Age-adjusted prevalence        38.3  ...                 35.2
# 10         Crude prevalence        37.1  ...                 36.5
# 11         Crude prevalence        37.3  ...                 30.6
# 12         Crude prevalence        27.3  ...                 25.8
# 13  Age-adjusted prevalence        30.3  ...                 24.4
# 14         Crude prevalence        26.4  ...                 26.3
# 15         Crude prevalence        16.8  ...                 14.6
# 16         Crude prevalence         2.9  ...                  2.6
# 17         Crude prevalence        23.1  ...                 19.5
# 18  Age-adjusted prevalence        29.0  ...                 25.6
# 19         Crude prevalence         4.5  ...                  4.1
#
#    high_confidence_limit  total_population  total_pop_18_plus location_id  \
# 0                   12.4            14,198             11,235        1027
# 1                   36.4            49,544             38,039        1045
# 2                    5.6            52,891             42,087        1071
# 3                   43.9            95,878             77,472        1077
# 4                   44.7            33,214             26,022        1079
# 5                   18.8           180,773            143,546        1081
# 6                    3.6           180,773            143,546        1081
# 7                   16.9            18,745             14,573        1091
# 8                    4.3            29,156             23,044        1093
# 9                   41.6           411,411            316,433        1097
# 10                  37.6            18,697             15,176        1107
# 11                  44.1             4,723              3,253        2070
# 12                  28.9             2,056              1,705        2100
# 13                  36.5            12,720              9,749        2150
# 14                  26.5           207,842            155,973        4027
# 15                  19.1            42,435             34,886        5005
# 16                   3.1           302,863            226,571        5007
# 17                  27.0             9,873              7,738        5017
# 18                  32.7            22,216             17,519        5027
# 19                   4.9            22,216             17,519        5027
#
#    category_id  measure_id data_value_type_id  short_question_text  \
# 0      HLTHOUT     CASTHMA             CrdPrv       Current Asthma
# 1      HLTHOUT   ARTHRITIS             CrdPrv            Arthritis
# 2      HLTHOUT      STROKE             CrdPrv               Stroke
# 3      HLTHOUT     OBESITY          AgeAdjPrv              Obesity
# 4      DISABLT  DISABILITY             CrdPrv       Any Disability
# 5      RISKBEH       BINGE          AgeAdjPrv       Binge Drinking
# 6      HLTHOUT      STROKE             CrdPrv               Stroke
# 7      RISKBEH       BINGE          AgeAdjPrv       Binge Drinking
# 8      HLTHOUT      STROKE          AgeAdjPrv               Stroke
# 9      HLTHOUT      BPHIGH          AgeAdjPrv  High Blood Pressure
# 10     HLTHOUT   ARTHRITIS             CrdPrv            Arthritis
# 11     HLTHOUT     OBESITY             CrdPrv              Obesity
# 12     HLTHOUT   ARTHRITIS             CrdPrv            Arthritis
# 13     HLTHOUT     OBESITY          AgeAdjPrv              Obesity
# 14     HLTHOUT   ARTHRITIS             CrdPrv            Arthritis
# 15     HLTHOUT    DIABETES             CrdPrv             Diabetes
# 16     HLTHOUT      STROKE             CrdPrv               Stroke
# 17     HLTHOUT  DEPRESSION             CrdPrv           Depression
# 18     HLTHOUT   ARTHRITIS          AgeAdjPrv            Arthritis
# 19     HLTHOUT      STROKE             CrdPrv               Stroke
#
#                                    geolocation
# 0   POINT (-85.8606604130173 33.2693085517833)
# 1   POINT (-85.6109266826185 31.4316629601359)
# 2   POINT (-85.9995052603961 34.7796392771775)
# 3   POINT (-87.6540983850983 34.9014438477101)
# 4   POINT (-87.3108851040374 34.5216735395968)
# 5    POINT (-85.3550362108983 32.601254498925)
# 6    POINT (-85.3550362108983 32.601254498925)
# 7   POINT (-87.7895124506775 32.2478854975948)
# 8   POINT (-87.8871984960778 34.1365876476739)
# 9     POINT (-88.20640909701 30.7791692937068)
# 10  POINT (-88.0891310718596 33.2807870081005)
# 11  POINT (-158.236178154164 59.7978171220014)
# 12   POINT (-135.500167586106 59.119335495324)
# 13  POINT (-153.789812278338 57.6808874751479)
# 14  POINT (-113.905997385394 32.7694427722845)
# 15  POINT (-92.3369593879758 36.2869936509323)
# 16  POINT (-94.2558310001198 36.3389781548829)
# 17  POINT (-91.2933505574654 33.2667470395332)
# 18  POINT (-93.2275288321248 33.2144070346383)
# 19  POINT (-93.2275288321248 33.2144070346383)
#
# [20 rows x 22 columns]

# %%
df.columns.tolist()
df.dtypes
# Out:
# year                            int64
# state_abbr                        str
# state_desc                        str
# location_name                     str
# data_source                       str
# category                          str
# measure                           str
# data_value_unit                   str
# data_value_type                   str
# data_value                    float64
# data_value_footnote_symbol     object
# data_value_footnote            object
# low_confidence_limit          float64
# high_confidence_limit         float64
# total_population                  str
# total_pop_18_plus                 str
# location_id                     int64
# category_id                       str
# measure_id                        str
# data_value_type_id                str
# short_question_text               str
# geolocation                       str
# dtype: object

# %%
fact_like = [
    "data_value",
    "low_confidence_limit",
    "high_confidence_limit",
    "total_population",
    "total_pop_18_plus",
]

dimension_like = [
    "year",
    "state_abbr",
    "state_desc",
    "location_name",
    "data_source",
    "category",
    "measure",
    "data_value_unit",
    "data_value_type",
    "location_id",
    "category_id",
    "measure_id",
    "data_value_type_id",
    "short_question_text",
    "geolocation",
]

print("Fact-like fields:", fact_like)
print("Dimension-like fields:", dimension_like)
# Out:
# Fact-like fields: ['data_value', 'low_confidence_limit', 'high_confidence_limit', 'total_population', 'total_pop_18_plus']
# Dimension-like fields: ['year', 'state_abbr', 'state_desc', 'location_name', 'data_source', 'category', 'measure', 'data_value_unit', 'data_value_type', 'location_id', 'category_id', 'measure_id', 'data_value_type_id', 'short_question_text', 'geolocation']

# %%
df[fact_like].head()
df[dimension_like].head()
# Out:
#    year state_abbr state_desc location_name data_source         category  \
# 0  2022         AL    Alabama          Clay       BRFSS  Health Outcomes
# 1  2022         AL    Alabama          Dale       BRFSS  Health Outcomes
# 2  2022         AL    Alabama       Jackson       BRFSS  Health Outcomes
# 3  2022         AL    Alabama    Lauderdale       BRFSS  Health Outcomes
# 4  2022         AL    Alabama      Lawrence       BRFSS       Disability
#
#                        measure data_value_unit          data_value_type  \
# 0  Current asthma among adults               %         Crude prevalence
# 1       Arthritis among adults               %         Crude prevalence
# 2          Stroke among adults               %         Crude prevalence
# 3         Obesity among adults               %  Age-adjusted prevalence
# 4  Any disability among adults               %         Crude prevalence
#
#    location_id category_id  measure_id data_value_type_id short_question_text  \
# 0         1027     HLTHOUT     CASTHMA             CrdPrv      Current Asthma
# 1         1045     HLTHOUT   ARTHRITIS             CrdPrv           Arthritis
# 2         1071     HLTHOUT      STROKE             CrdPrv              Stroke
# 3         1077     HLTHOUT     OBESITY          AgeAdjPrv             Obesity
# 4         1079     DISABLT  DISABILITY             CrdPrv      Any Disability
#
#                                   geolocation
# 0  POINT (-85.8606604130173 33.2693085517833)
# 1  POINT (-85.6109266826185 31.4316629601359)
# 2  POINT (-85.9995052603961 34.7796392771775)
# 3  POINT (-87.6540983850983 34.9014438477101)
# 4  POINT (-87.3108851040374 34.5216735395968)
